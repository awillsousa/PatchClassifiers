# %%
import numpy as np
import mahotas as mh
import matplotlib.pyplot as plt
from PIL import Image
import IPython.display as display

# %%
arqimg = "/home/willian/bases/cancer/2imgs/SOB_M_PC-15-190EF-400-004.png"
img = mh.imread(arqimg)
plt.imshow(img)
plt.show()
imgcopy = img.copy()
imgcopy[:, :, 2] = 0
imgcopy[:, :, 0] = 0
plt.imshow(imgcopy)
plt.show()
